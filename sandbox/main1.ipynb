# %%
import cv2
import numpy as np
#import matplotlib.pylot as plt
#import os

# %%
template = cv2.imread("../PCBdata/template/001.png",0);
test = cv2.imread("../PCBdata/test/001.png",0);
# Out:
# [ WARN:0@97.858] global loadsave.cpp:275 findDecoder imread_('../PCBdata/template/001.png'): can't open/read file: check file path/integrity
# [ WARN:0@97.859] global loadsave.cpp:275 findDecoder imread_('../PCBdata/test/001.png'): can't open/read file: check file path/integrity

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.12.0

# %%
test = cv2.resize(test,(template.shape[1], template.shape[0]))
diff = cv2.absdiff(template, test)
_, diff = cv2.threshold(diff, 30, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU  )

cv2.imshow("diff",mask)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 test = cv2.resize(test,(template.shape[1], template.shape[0]))
#       2 diff = cv2.absdiff(template, test)
#       3 _, diff = cv2.threshold(diff, 30, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU  )
#
# AttributeError: 'NoneType' object has no attribute 'shape'
